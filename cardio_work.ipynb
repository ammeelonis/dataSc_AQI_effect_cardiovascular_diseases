# %%
import scipy

# %%
import numpy

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sb

# %%
import pandas as pd

# %%
df_cardio = pd.read_csv("National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data.csv")

# %%
df_cardio
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 0      2014           AL      Alabama       NVSS  Million Hearts
# 1      2014           AL      Alabama       NVSS  Million Hearts
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 3      2014           AL      Alabama       NVSS  Million Hearts
# 4      2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41595  2018           WY      Wyoming       NVSS            None
# 41596  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
# 41599  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 0              None          None          None  Cardiovascular Diseases
# ...

# %%
df_heart_attack = df_cardio.loc[df_cardio['Topic'] == 'Acute Myocardial Infarction (Heart Attack)']

# %%
df_heart_attack
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 0      2014           AL      Alabama       NVSS  Million Hearts
# 1      2014           AL      Alabama       NVSS  Million Hearts
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 3      2014           AL      Alabama       NVSS  Million Hearts
# 4      2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41455  2018           WY      Wyoming       NVSS  Million Hearts
# 41456  2018           WY      Wyoming       NVSS  Million Hearts
# 41457  2018           WY      Wyoming       NVSS  Million Hearts
# 41458  2018           WY      Wyoming       NVSS  Million Hearts
# 41459  2018           WY      Wyoming       NVSS  Million Hearts
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 0              None          None          None  Cardiovascular Diseases
# ...

# %%
df_stroke = df_cardio.loc[df_cardio['Topic'] == 'Stroke']

# %%
df_stroke
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 20     2014           AL      Alabama       NVSS  Million Hearts
# 21     2014           AL      Alabama       NVSS  Million Hearts
# 22     2014           AL      Alabama       NVSS  Million Hearts
# 23     2014           AL      Alabama       NVSS  Million Hearts
# 24     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41595  2018           WY      Wyoming       NVSS            None
# 41596  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
# 41599  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2        PriorityArea3 PriorityArea4  \
# 20             None  Healthy People 2020          None
# 21             None  Healthy People 2020          None
# ...

# %%
df_race = df_cardio.loc[df_cardio['Break_Out_Category'] == 'Race']

# %%
df_gender = df_cardio.loc[df_cardio['Break_Out_Category'] == 'Gender']

# %%
df_age = df_cardio.loc[df_cardio['Break_Out_Category'] == 'Age']

# %%
df_overall = df_cardio.loc[df_cardio['Break_Out_Category'] == 'Overall']

# %%
df_race
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 5      2014           AL      Alabama       NVSS  Million Hearts
# 6      2014           AL      Alabama       NVSS  Million Hearts
# 7      2014           AL      Alabama       NVSS  Million Hearts
# 11     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41589  2018           WY      Wyoming       NVSS            None
# 41590  2018           WY      Wyoming       NVSS            None
# 41594  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 2              None          None          None  Cardiovascular Diseases
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
plt.bar(df_race.Topic, df_race.Data_Value_Alt)

plt.title("Chart showing distribution of cardiovascular diseases prevalence rate per 1000")
#plt.rcParams['figure.figsize'] = [12, 8]
plt.style.use('seaborn-white')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)
plt.savefig('Cardiovascular_disease_prevalence')
plt.show()

# %%
df_race
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 5      2014           AL      Alabama       NVSS  Million Hearts
# 6      2014           AL      Alabama       NVSS  Million Hearts
# 7      2014           AL      Alabama       NVSS  Million Hearts
# 11     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41589  2018           WY      Wyoming       NVSS            None
# 41590  2018           WY      Wyoming       NVSS            None
# 41594  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 2              None          None          None  Cardiovascular Diseases
# ...

# %%
plt.plot(df_race.Break_Out, df_race.Data_Value_Alt)

plt.title("Chart showing distribution of cardiovascular diseases prevalence rate per 1000 by race")
#plt.rcParams['figure.figsize'] = [12, 8]
plt.style.use('seaborn-white')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)
plt.savefig('Cardiovascular_disease_prevalence_race')
plt.show()

# %%
#corrMatrix = df_race.corr()
#sn.heatmap(corrMatrix, annot=True)
#plt.savefig('df_race_corr.png')
#plt.show()

#plt.figure(figsize=(12, 4))
#a = sns.boxplot(db.DMDEDUC2x, db.RIDAGEYR)

new_race_frame = df_race[["Topic", "Break_Out", "Data_Value_Alt"]]

# %%
new_race_frame
# Out:
#                                             Topic           Break_Out  \
# 2      Acute Myocardial Infarction (Heart Attack)            Hispanic
# 5      Acute Myocardial Infarction (Heart Attack)  Non-Hispanic Black
# 6      Acute Myocardial Infarction (Heart Attack)  Non-Hispanic White
# 7      Acute Myocardial Infarction (Heart Attack)            Hispanic
# 11     Acute Myocardial Infarction (Heart Attack)               Other
# ...                                           ...                 ...
# 41589                                      Stroke            Hispanic
# 41590                                      Stroke  Non-Hispanic Black
# 41594                                      Stroke            Hispanic
# 41597                                      Stroke               Other
# 41598                                      Stroke  Non-Hispanic White
#
#        Data_Value_Alt
# 2                -2.0
# 5                46.5
# 6                62.4
# 7                -2.0
# ...

# %%
plt.bar(df_heart_attack.Break_Out, df_heart_attack.Data_Value_Alt)

plt.title("Chart showing distribution of cardiovascular diseases prevalence rate per 1000 by race")
#plt.rcParams['figure.figsize'] = [12, 8]
plt.style.use('seaborn-white')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)
plt.savefig('Cardiovascular_disease_prevalence_race_age')
plt.show()

# %%
df_race
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 5      2014           AL      Alabama       NVSS  Million Hearts
# 6      2014           AL      Alabama       NVSS  Million Hearts
# 7      2014           AL      Alabama       NVSS  Million Hearts
# 11     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41589  2018           WY      Wyoming       NVSS            None
# 41590  2018           WY      Wyoming       NVSS            None
# 41594  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 2              None          None          None  Cardiovascular Diseases
# ...

# %%
df_heart_attack_race = df_race[df_race["Topic"] == 'Acute Myocardial Infarction (Heart Attack)']

# %%
df_heart_attack_race
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 5      2014           AL      Alabama       NVSS  Million Hearts
# 6      2014           AL      Alabama       NVSS  Million Hearts
# 7      2014           AL      Alabama       NVSS  Million Hearts
# 11     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41449  2018           WY      Wyoming       NVSS  Million Hearts
# 41450  2018           WY      Wyoming       NVSS  Million Hearts
# 41454  2018           WY      Wyoming       NVSS  Million Hearts
# 41456  2018           WY      Wyoming       NVSS  Million Hearts
# 41459  2018           WY      Wyoming       NVSS  Million Hearts
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 2              None          None          None  Cardiovascular Diseases
# ...

# %%
plt.bar(df_heart_attack_race.Break_Out, df_heart_attack_race.Data_Value_Alt)

plt.title("Chart showing distribution of Acute Myocardial Infarction (Heart Attack) rate per 1000 by race")
plt.rcParams['figure.figsize'] = [12, 10]
plt.style.use('seaborn-white')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_attack_race.Break_Out
y = df_heart_attack_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_attack_prevalence_race')
plt.show()

# %%
df_heart_attack_age = df_age[df_age["Topic"] == 'Acute Myocardial Infarction (Heart Attack)']

# %%
plt.bar(df_heart_attack_age.Break_Out, df_heart_attack_age.Data_Value_Alt)

plt.title("Chart showing distribution of Acute Myocardial Infarction (Heart Attack) rate per 1000 by age")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_attack_age.Break_Out
y = df_heart_attack_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))
    
plt.savefig('heart_attack_prevalence_age')
plt.show()

# %%
df_heart_attack_gender = df_gender[df_gender["Topic"] == 'Acute Myocardial Infarction (Heart Attack)']

# %%
plt.bar(df_heart_attack_gender.Break_Out, df_heart_attack_gender.Data_Value_Alt)

plt.title("Chart showing distribution of Acute Myocardial Infarction (Heart Attack) rate per 1000 by gender")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_attack_gender.Break_Out
y = df_heart_attack_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_attack_prevalence_gender')
plt.show()

# %%
df_heart_attack_overall = df_overall[df_overall["Topic"] == 'Acute Myocardial Infarction (Heart Attack)']

# %%
df_heart_attack_overall
# Out:
#        Year LocationAbbr   LocationDesc DataSource   PriorityArea1  \
# 1      2014           AL        Alabama       NVSS  Million Hearts
# 8      2014           AL        Alabama       NVSS  Million Hearts
# 163    2014           AK         Alaska       NVSS  Million Hearts
# 164    2014           AK         Alaska       NVSS  Million Hearts
# 322    2014           AZ        Arizona       NVSS  Million Hearts
# ...     ...          ...            ...        ...             ...
# 41131  2018           WV  West Virginia       NVSS  Million Hearts
# 41283  2018           WI      Wisconsin       NVSS  Million Hearts
# 41287  2018           WI      Wisconsin       NVSS  Million Hearts
# 41440  2018           WY        Wyoming       NVSS  Million Hearts
# 41455  2018           WY        Wyoming       NVSS  Million Hearts
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 1              None          None          None  Cardiovascular Diseases
# ...

# %%
df_stroke_race = df_race[df_race["Topic"] == 'Stroke']

# %%
df_race
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 5      2014           AL      Alabama       NVSS  Million Hearts
# 6      2014           AL      Alabama       NVSS  Million Hearts
# 7      2014           AL      Alabama       NVSS  Million Hearts
# 11     2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41589  2018           WY      Wyoming       NVSS            None
# 41590  2018           WY      Wyoming       NVSS            None
# 41594  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 2              None          None          None  Cardiovascular Diseases
# ...

# %%
plt.bar(df_stroke_race.Break_Out, df_stroke_race.Data_Value_Alt)

plt.title("Chart showing distribution of stroke rate per 1000 by race")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_stroke_race.Break_Out
y = df_stroke_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('stroke_prevalence_race')
plt.show()

# %%
df_stroke_age = df_age[df_age["Topic"] == 'Stroke']

# %%
plt.bar(df_stroke_age.Break_Out, df_stroke_age.Data_Value_Alt)

plt.title("Chart showing distribution of stroke rate per 1000 by age")
plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_stroke_age.Break_Out
y = df_stroke_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('stroke_prevalence_age')
plt.show()

# %%
df_stroke_gender = df_gender[df_gender["Topic"] == 'Stroke']

# %%
plt.bar(df_stroke_gender.Break_Out, df_stroke_gender.Data_Value_Alt)

plt.title("Chart showing distribution of stroke rate per 1000 by gender")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_stroke_gender.Break_Out
y = df_stroke_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('stroke_prevalence_gender')
plt.show()

# %%
df_major_cardiovascular_disease_race = df_race[df_race["Topic"] == 'Major Cardiovascular Disease']

# %%
plt.bar(df_major_cardiovascular_disease_race.Break_Out, df_major_cardiovascular_disease_race.Data_Value_Alt, color='brown')

plt.title("Chart showing distribution of Major Cardiovascular Disease rate per 1000 by race")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_major_cardiovascular_disease_race.Break_Out
y = df_major_cardiovascular_disease_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('major_cardiovascular_disease_prevalence_race')
plt.show()

# %%
df_major_cardiovascular_disease_age = df_age[df_age["Topic"] == 'Major Cardiovascular Disease']

# %%
plt.bar(df_major_cardiovascular_disease_age.Break_Out, df_major_cardiovascular_disease_age.Data_Value_Alt, color='brown')

plt.title("Chart showing distribution of Major Cardiovascular Disease rate per 1000 by age")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_major_cardiovascular_disease_age.Break_Out
y = df_major_cardiovascular_disease_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('major_cardiovascular_disease_prevalence_age')
plt.show()

# %%
df_major_cardiovascular_disease_gender = df_gender[df_gender["Topic"] == 'Major Cardiovascular Disease']

# %%
plt.bar(df_major_cardiovascular_disease_gender.Break_Out, df_major_cardiovascular_disease_gender.Data_Value_Alt, color='brown')

plt.title("Chart showing distribution of Major Cardiovascular Disease rate per 1000 by gender")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_major_cardiovascular_disease_gender.Break_Out
y = df_major_cardiovascular_disease_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('major_cardiovascular_disease_prevalence_gender')
plt.show()

# %%
df_heart_disease_race = df_race[df_race["Topic"] == 'Diseases of the Heart (Heart Disease)']

# %%
plt.bar(df_heart_disease_race.Break_Out, df_heart_disease_race.Data_Value_Alt, color='grey')

plt.title("Chart showing distribution of Diseases of the Heart (Heart Disease) rate per 1000 by race")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_disease_race.Break_Out
y = df_heart_disease_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_disease_prevalence_gender')
plt.show()

# %%
df_heart_disease_age = df_age[df_age["Topic"] == 'Diseases of the Heart (Heart Disease)']

# %%
plt.bar(df_heart_disease_age.Break_Out, df_heart_disease_age.Data_Value_Alt, color='grey')

plt.title("Chart showing distribution of Diseases of the Heart (Heart Disease) rate per 1000 by Age")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_disease_age.Break_Out
y = df_heart_disease_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_disease_prevalence_age')
plt.show()

# %%
df_heart_disease_gender = df_gender[df_gender["Topic"] == 'Diseases of the Heart (Heart Disease)']

# %%
plt.bar(df_heart_disease_gender.Break_Out, df_heart_disease_gender.Data_Value_Alt, color='grey')

plt.title("Chart showing distribution of Diseases of the Heart (Heart Disease) rate per 1000 by Gender")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_disease_gender.Break_Out
y = df_heart_disease_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_disease_prevalence_gender')
plt.show()

# %%
df_coronary_heart_disease_race = df_race[df_race["Topic"] == 'Coronary Heart Disease']

# %%
plt.bar(df_coronary_heart_disease_race.Break_Out, df_coronary_heart_disease_race.Data_Value_Alt, color='cyan')

plt.title("Chart showing distribution of Coronary Heart Disease rate per 1000 by Race")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_coronary_heart_disease_race.Break_Out
y = df_coronary_heart_disease_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('coronary_heart_disease_prevalence_race')
plt.show()

# %%
df_coronary_heart_disease_age = df_age[df_age["Topic"] == 'Coronary Heart Disease']

# %%
plt.bar(df_coronary_heart_disease_age.Break_Out, df_coronary_heart_disease_age.Data_Value_Alt, color='cyan')

plt.title("Chart showing distribution of Coronary Heart Disease rate per 1000 by Age")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_coronary_heart_disease_age.Break_Out
y = df_coronary_heart_disease_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('coronary_heart_disease_prevalence_age')
plt.show()

# %%
df_coronary_heart_disease_gender = df_gender[df_gender["Topic"] == 'Coronary Heart Disease']

# %%
plt.bar(df_coronary_heart_disease_gender.Break_Out, df_coronary_heart_disease_gender.Data_Value_Alt, color='cyan')

plt.title("Chart showing distribution of Coronary Heart Disease rate per 1000 by Gender")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_coronary_heart_disease_gender.Break_Out
y = df_coronary_heart_disease_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('coronary_heart_disease_prevalence_Gender')
plt.show()

# %%
df_heart_failure_race = df_race[df_race["Topic"] == 'Heart Failure']

# %%
plt.bar(df_heart_failure_race.Break_Out, df_heart_failure_race.Data_Value_Alt, color='magenta')

plt.title("Chart showing distribution of Heart Failure rate per 1000 by Race")
plt.rcParams['figure.figsize'] = [12, 10]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_failure_race.Break_Out
y = df_heart_failure_race.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_failure_prevalence_race')
plt.show()

# %%
df_heart_failure_age = df_age[df_age["Topic"] == 'Heart Failure']

# %%
plt.bar(df_heart_failure_age.Break_Out, df_heart_failure_age.Data_Value_Alt, color='magenta')

plt.title("Chart showing distribution of Heart Failure rate per 1000 by Age")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_failure_age.Break_Out
y = df_heart_failure_age.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_failure_prevalence_age')
plt.show()

# %%
df_heart_failure_gender = df_gender[df_gender["Topic"] == 'Heart Failure']

# %%
plt.bar(df_heart_failure_gender.Break_Out, df_heart_failure_gender.Data_Value_Alt, color='magenta')

plt.title("Chart showing distribution of Heart Failure rate per 1000 by Gender")
#plt.rcParams['figure.figsize'] = [12, 8]
#plt.style.use('seaborn-blue')
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

x = df_heart_failure_gender.Break_Out
y = df_heart_failure_gender.Data_Value_Alt

for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i,j))

plt.savefig('heart_failure_prevalence_gender')
plt.show()
