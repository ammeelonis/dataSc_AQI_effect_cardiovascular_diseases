# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib as mpl

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sn

# %%
import scipy as scp

# %%
print(mpl.get_cachedir())
# Out:
# C:\Users\Ammi\.matplotlib

# %%
aqi_2014 = pd.read_csv("annual_aqi_by_county_2014.csv")

# %%
aqi_2014
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2014            280        232             46
# 1     Alabama        Clay  2014            114         96             18
# 2     Alabama     Colbert  2014            284        251             33
# 3     Alabama      DeKalb  2014            360        313             47
# 4     Alabama      Elmore  2014            245        224             21
# ...       ...         ...   ...            ...        ...            ...
# 1049  Wyoming    Sublette  2014            365        286             79
# 1050  Wyoming  Sweetwater  2014            365        246            111
# 1051  Wyoming       Teton  2014            365        320             45
# 1052  Wyoming       Uinta  2014            365        331             34
# 1053  Wyoming      Weston  2014            365        331             34
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# ...

# %%
aqi_2014.describe()
# Out:
#          Year  Days with AQI    Good Days  Moderate Days  \
# count  1054.0    1054.000000  1054.000000    1054.000000
# mean   2014.0     312.163188   245.388046      62.637571
# std       0.0      86.632197    80.104717      51.051801
# min    2014.0       1.000000     1.000000       0.000000
# 25%    2014.0     280.000000   194.000000      24.000000
# 50%    2014.0     362.000000   262.000000      48.000000
# 75%    2014.0     365.000000   308.000000      93.750000
# max    2014.0     365.000000   365.000000     279.000000
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# count                          1054.000000     1054.000000
# mean                              3.475332        0.609108
# std                              11.230591        5.121408
# min                               0.000000        0.000000
# 25%                               0.000000        0.000000
# 50%                               1.000000        0.000000
# ...

# %%
described_2014 = aqi_2014.describe()

# %%
described_2014
# Out:
#          Year  Days with AQI    Good Days  Moderate Days  \
# count  1054.0    1054.000000  1054.000000    1054.000000
# mean   2014.0     312.163188   245.388046      62.637571
# std       0.0      86.632197    80.104717      51.051801
# min    2014.0       1.000000     1.000000       0.000000
# 25%    2014.0     280.000000   194.000000      24.000000
# 50%    2014.0     362.000000   262.000000      48.000000
# 75%    2014.0     365.000000   308.000000      93.750000
# max    2014.0     365.000000   365.000000     279.000000
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# count                          1054.000000     1054.000000
# mean                              3.475332        0.609108
# std                              11.230591        5.121408
# min                               0.000000        0.000000
# 25%                               0.000000        0.000000
# 50%                               1.000000        0.000000
# ...

# %%
plt.plot("2014", described_2014.mean)
plt.plot("2014", described_2014.std)
plt.title("Test Plot")
plt.xlabel("Year")
plt.ylabel ("Mean & Standard Deviation")
plt.legend (["Mean", "Standard Deviation"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6f497079cb93> in <module>
# ----> 1 plt.plot("2014", described_2014.mean)
#       2 plt.plot("2014", described_2014.std)
#       3 plt.title("Test Plot")
#       4 plt.xlabel("Year")
#       5 plt.ylabel ("Mean & Standard Deviation")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
aqi_2014
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2014            280        232             46
# 1     Alabama        Clay  2014            114         96             18
# 2     Alabama     Colbert  2014            284        251             33
# 3     Alabama      DeKalb  2014            360        313             47
# 4     Alabama      Elmore  2014            245        224             21
# ...       ...         ...   ...            ...        ...            ...
# 1049  Wyoming    Sublette  2014            365        286             79
# 1050  Wyoming  Sweetwater  2014            365        246            111
# 1051  Wyoming       Teton  2014            365        320             45
# 1052  Wyoming       Uinta  2014            365        331             34
# 1053  Wyoming      Weston  2014            365        331             34
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# ...

# %%
alabama_aqi = aqi_2014[aqi_2014.State == "Alabama"]

# %%
alabama_aqi
# Out:
#       State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0   Alabama     Baldwin  2014            280        232             46
# 1   Alabama        Clay  2014            114         96             18
# 2   Alabama     Colbert  2014            284        251             33
# 3   Alabama      DeKalb  2014            360        313             47
# 4   Alabama      Elmore  2014            245        224             21
# 5   Alabama      Etowah  2014            281        244             37
# 6   Alabama     Houston  2014            279        241             38
# 7   Alabama   Jefferson  2014            365        158            201
# 8   Alabama    Lawrence  2014            104         92             12
# 9   Alabama     Madison  2014            338        281             57
# 10  Alabama      Mobile  2014            285        224             55
# 11  Alabama  Montgomery  2014            284        235             49
# ...

# %%
plt.plot(alabama_aqi.County, alabama_aqi.Moderate%20Days)

plt.title("Test Plot")
plt.show()
# Out:
#   File "<ipython-input-31-7e2342fc8776>", line 1
#     plt.plot(alabama_aqi.County, alabama_aqi.Moderate%20Days)
#                                                         ^
# SyntaxError: invalid syntax

# %%
alabama_aqi.columns = alabama_aqi.columns.str.replace(' ', '_')

# %%
alabama_aqi
# Out:
#       State      County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0   Alabama     Baldwin  2014            280        232             46
# 1   Alabama        Clay  2014            114         96             18
# 2   Alabama     Colbert  2014            284        251             33
# 3   Alabama      DeKalb  2014            360        313             47
# 4   Alabama      Elmore  2014            245        224             21
# 5   Alabama      Etowah  2014            281        244             37
# 6   Alabama     Houston  2014            279        241             38
# 7   Alabama   Jefferson  2014            365        158            201
# 8   Alabama    Lawrence  2014            104         92             12
# 9   Alabama     Madison  2014            338        281             57
# 10  Alabama      Mobile  2014            285        224             55
# 11  Alabama  Montgomery  2014            284        235             49
# ...

# %%
plt.plot(alabama_aqi.County, alabama_aqi.Moderate_Days)
plt.plot(alabama_aqi.County, alabama_aqi.Good_Days)
plt.rcParams['figure.figsize'] = [12, 8]
#plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

plt.title("Test Plot")
plt.savefig('test.png')
plt.show()

# %%
corrMatrix = alabama_aqi.corr()
sn.heatmap(corrMatrix, annot=True)
plt.savefig('test_corr.png')
plt.show()

# %%
df_cardio = pd.read_csv("National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data.csv")

# %%
df_cardio
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 0      2014           AL      Alabama       NVSS  Million Hearts
# 1      2014           AL      Alabama       NVSS  Million Hearts
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 3      2014           AL      Alabama       NVSS  Million Hearts
# 4      2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41595  2018           WY      Wyoming       NVSS            None
# 41596  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
# 41599  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 0              None          None          None  Cardiovascular Diseases
# ...

# %%
df_cardio
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 0      2014           AL      Alabama       NVSS  Million Hearts
# 1      2014           AL      Alabama       NVSS  Million Hearts
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 3      2014           AL      Alabama       NVSS  Million Hearts
# 4      2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41595  2018           WY      Wyoming       NVSS            None
# 41596  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
# 41599  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 0              None          None          None  Cardiovascular Diseases
# ...

# %%
df_cardio.describe()
# Out:
#                Year    Data_Value  Data_Value_Alt  LowConfidenceLimit  \
# count  41600.000000  34503.000000    41600.000000        34503.000000
# mean    2016.000000    165.084810      136.579981          164.937107
# std        1.414231    328.372662      305.585983          328.407576
# min     2014.000000      0.100000       -2.000000            0.100000
# 25%     2015.000000     23.600000       11.500000           23.400000
# 50%     2016.000000     54.200000       38.700000           54.100000
# 75%     2017.000000    189.500000      147.400000          189.400000
# max     2018.000000   3157.500000     3157.500000         3157.500000
#
#        HighConfidenceLimit    LocationID
# count         34503.000000  41600.000000
# mean            167.045779     29.538462
# std             327.989285     16.064321
# min               0.100000      1.000000
# 25%              25.400000     16.750000
# 50%              56.300000     29.500000
# 75%             192.700000     42.500000
# ...

# %%
df_cardio = pd.read_csv("National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4b00c6b6cc0a> in <module>
# ----> 1 df_cardio = pd.read_csv("National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data.csv")
#
# NameError: name 'pd' is not defined

# %%
df_cardio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38e4a594e6eb> in <module>
# ----> 1 df_cardio
#
# NameError: name 'df_cardio' is not defined

# %%
import numpy as np

# %%
import scipy as sp

# %%
import pandas as pd

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sb

# %%
df_aqi_2014 = pd.read_csv ("annual_aqi_by_county_2014.csv")

# %%
df_aqi_2014
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2014            280        232             46
# 1     Alabama        Clay  2014            114         96             18
# 2     Alabama     Colbert  2014            284        251             33
# 3     Alabama      DeKalb  2014            360        313             47
# 4     Alabama      Elmore  2014            245        224             21
# ...       ...         ...   ...            ...        ...            ...
# 1049  Wyoming    Sublette  2014            365        286             79
# 1050  Wyoming  Sweetwater  2014            365        246            111
# 1051  Wyoming       Teton  2014            365        320             45
# 1052  Wyoming       Uinta  2014            365        331             34
# 1053  Wyoming      Weston  2014            365        331             34
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# ...

# %%
df_aqi_2014.columns = df_aqi_2014.columns.str.replace(' ', '_')

# %%
plt.scatter(df_aqi_2014.State, df_aqi_2014.Moderate_Days, label = 'Moderate Days')
plt.scatter(df_aqi_2014.State, df_aqi_2014.Good_Days, label = 'Good Days')
plt.scatter(df_aqi_2014.State, df_aqi_2014.Unhealthy_for_Sensitive_Groups_Days, label = 'Unhealthy for sensitive groups Days')
plt.scatter(df_aqi_2014.State, df_aqi_2014.Unhealthy_Days, label = 'Unhealthy Days')
plt.scatter(df_aqi_2014.State, df_aqi_2014.Very_Unhealthy_Days, label = 'Very Unhealthy Days')
plt.scatter(df_aqi_2014.State, df_aqi_2014.Hazardous_Days, label = 'Hazardous Days')
plt.legend(framealpha=1, frameon=True)
#plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower
plt.xticks(rotation=90)

plt.title("Test Plot AQIs")
plt.savefig('test_aqi.png')
plt.show()

# %%
data_summary = df_aqi_2014.describe

# %%
data_summary
# Out:
# <bound method NDFrame.describe of         State      County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0     Alabama     Baldwin  2014            280        232             46
# 1     Alabama        Clay  2014            114         96             18
# 2     Alabama     Colbert  2014            284        251             33
# 3     Alabama      DeKalb  2014            360        313             47
# 4     Alabama      Elmore  2014            245        224             21
# ...       ...         ...   ...            ...        ...            ...
# 1049  Wyoming    Sublette  2014            365        286             79
# 1050  Wyoming  Sweetwater  2014            365        246            111
# 1051  Wyoming       Teton  2014            365        320             45
# 1052  Wyoming       Uinta  2014            365        331             34
# 1053  Wyoming      Weston  2014            365        331             34
#
# ...

# %%
df_aqi_2014
# Out:
#         State      County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0     Alabama     Baldwin  2014            280        232             46
# 1     Alabama        Clay  2014            114         96             18
# 2     Alabama     Colbert  2014            284        251             33
# 3     Alabama      DeKalb  2014            360        313             47
# 4     Alabama      Elmore  2014            245        224             21
# ...       ...         ...   ...            ...        ...            ...
# 1049  Wyoming    Sublette  2014            365        286             79
# 1050  Wyoming  Sweetwater  2014            365        246            111
# 1051  Wyoming       Teton  2014            365        320             45
# 1052  Wyoming       Uinta  2014            365        331             34
# 1053  Wyoming      Weston  2014            365        331             34
#
#       Unhealthy_for_Sensitive_Groups_Days  Unhealthy_Days  \
# ...

# %%
alabama_df = df_aqi_2014.loc[df_aqi_2014["State"] == "Alabama"]

# %%
alabama_df
# Out:
#       State      County  Year  Days_with_AQI  Good_Days  Moderate_Days  \
# 0   Alabama     Baldwin  2014            280        232             46
# 1   Alabama        Clay  2014            114         96             18
# 2   Alabama     Colbert  2014            284        251             33
# 3   Alabama      DeKalb  2014            360        313             47
# 4   Alabama      Elmore  2014            245        224             21
# 5   Alabama      Etowah  2014            281        244             37
# 6   Alabama     Houston  2014            279        241             38
# 7   Alabama   Jefferson  2014            365        158            201
# 8   Alabama    Lawrence  2014            104         92             12
# 9   Alabama     Madison  2014            338        281             57
# 10  Alabama      Mobile  2014            285        224             55
# 11  Alabama  Montgomery  2014            284        235             49
# ...

# %%
df_cardio = pd.read_csv("National_Vital_Statistics_System__NVSS__-_National_Cardiovascular_Disease_Surveillance_Data.csv")

# %%
df_cardio
# Out:
#        Year LocationAbbr LocationDesc DataSource   PriorityArea1  \
# 0      2014           AL      Alabama       NVSS  Million Hearts
# 1      2014           AL      Alabama       NVSS  Million Hearts
# 2      2014           AL      Alabama       NVSS  Million Hearts
# 3      2014           AL      Alabama       NVSS  Million Hearts
# 4      2014           AL      Alabama       NVSS  Million Hearts
# ...     ...          ...          ...        ...             ...
# 41595  2018           WY      Wyoming       NVSS            None
# 41596  2018           WY      Wyoming       NVSS            None
# 41597  2018           WY      Wyoming       NVSS            None
# 41598  2018           WY      Wyoming       NVSS            None
# 41599  2018           WY      Wyoming       NVSS            None
#
#       PriorityArea2 PriorityArea3 PriorityArea4                 Category  \
# 0              None          None          None  Cardiovascular Diseases
# ...

# %%
#Carlifornia
df_aqi_carlifornia = aqi_2014_2018[aqi2014_2018['State'] == "Carlifornia"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-780a0958654c> in <module>
#       1 #Carlifornia
# ----> 2 df_aqi_carlifornia = aqi_2014_2018[aqi2014_2018['State'] == "Carlifornia"]
#
# NameError: name 'aqi_2014_2018' is not defined
